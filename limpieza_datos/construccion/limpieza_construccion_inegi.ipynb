# %%
#Importación de librerías 
import pandas as pd

# %%
# Leemos todas las hojas
data_inegi= pd.read_excel("contruccion.xlsx")

# %%
data_inegi.head(10)
# Out:
#   Instituto Nacional de Estadística y Geografía (INEGI)  Unnamed: 1  \
# 0                                                NaN            NaN
# 1                                      Construcción.            NaN
# 2                                                NaN            NaN
# 3  Series desestacionalizadas del valor total de ...            NaN
# 4                     (Variación porcentual mensual)            NaN
# 5                                            Periodo            NaN
# 6                                               2012            NaN
# 7                                              Enero            NaN
# 8                                            Febrero            NaN
# 9                                              Marzo            NaN
#
#   Unnamed: 2   Unnamed: 3                 Unnamed: 4  \
# 0        NaN          NaN                        NaN
# 1        NaN          NaN                        NaN
# 2        NaN          NaN                        NaN
# 3        NaN          NaN                        NaN
# 4        NaN          NaN                        NaN
# 5      Total  Edificación  Agua, riego y saneamiento
# 6        NaN          NaN                        NaN
# 7       -4.2         -0.3                        5.5
# 8        0.4          0.1                       -5.1
# 9        0.4         -0.4                          4
#
#                       Unnamed: 5  Unnamed: 6               Unnamed: 7  \
# 0                            NaN         NaN                      NaN
# 1                            NaN         NaN                      NaN
# 2                            NaN         NaN                      NaN
# 3                            NaN         NaN                      NaN
# 4                            NaN         NaN                      NaN
# 5  Electricidad y comunicaciones  Transporte  Petróleo y petroquímica
# 6                            NaN         NaN                      NaN
# 7                           -0.9        -5.8                     -3.4
# 8                           -5.1         1.9                     -3.5
# 9                           -1.3         1.9                     10.3
#
#              Unnamed: 8
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5  Otras construcciones
# 6                   NaN
# 7                  -3.2
# 8                   3.7
# 9                  -0.9

# %%
data = data_inegi.copy()

# %%
data.drop(data.columns[1], axis=1, inplace = True)
data.columns = data.iloc[5]
data = data[6:]

# %%
data.head()
# Out:
# 5   Periodo Total Edificación Agua, riego y saneamiento  \
# 6      2012   NaN         NaN                       NaN
# 7     Enero  -4.2        -0.3                       5.5
# 8   Febrero   0.4         0.1                      -5.1
# 9     Marzo   0.4        -0.4                         4
# 10    Abril     0         4.9                      -9.9
#
# 5  Electricidad y comunicaciones Transporte Petróleo y petroquímica  \
# 6                            NaN        NaN                     NaN
# 7                           -0.9       -5.8                    -3.4
# 8                           -5.1        1.9                    -3.5
# 9                           -1.3        1.9                    10.3
# 10                          -2.6        0.5                    -4.5
#
# 5  Otras construcciones
# 6                   NaN
# 7                  -3.2
# 8                   3.7
# 9                  -0.9
# 10                  0.3

# %%
filas = [] 

for i in range(0, len(data), 13):
    bloque = data.iloc[i:i+13].copy()     
    anio = bloque.iloc[0]['Periodo']  
    bloque = bloque.iloc[1:]         
    bloque['Año'] = anio            
    filas.append(bloque)           

df_procesado = pd.concat(filas, ignore_index=True)

# %%
df_procesado = df_procesado[:157]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def make_plots_cuantitativas(dataframe):
    df = dataframe.copy()

    # Seleccionar  variables cuantitativas
    quant_vars = ["Total",	"Edificación",	"Agua, riego y saneamiento",	"Electricidad y comunicaciones",	"Transporte",	"Petróleo y petroquímica"	,"Otras construcciones"]

    # ===== 1. Boxplots (cuartiles y outliers) =====
    plt.figure(figsize=(12, 6))
    for i, col in enumerate(quant_vars):
        plt.subplot(1, len(quant_vars), i+1)
        sns.boxplot(y=df[col])
        plt.title(f'Boxplot: {col}')
    plt.tight_layout()
    plt.show()

    # ===== 2. Histogramas (distribución, simetría/asimetría) =====
    plt.figure(figsize=(12, 8))
    for i, col in enumerate(quant_vars):
        plt.subplot(2, 4, i+1)
        sns.histplot(df[col], kde=True)
        plt.title(f'Histograma: {col}')
    plt.tight_layout()
    plt.show()

    # ===== 3. Análisis de correlación - Heatmap =====
    plt.figure(figsize=(8, 6))
    corr = df[quant_vars].corr()
    sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title('Mapa de calor de correlaciones')
    plt.show()

# %%
make_plots_cuantitativas(df_procesado)

# %%
def agregar_columna_fecha(df):
    """Convierte columnas 'Año' y 'Mes' en una columna Period 'Fecha' (formato año-mes), colocándola como la primera columna."""
    meses = {
        'Enero': 1, 'Febrero': 2, 'Marzo': 3, 'Abril': 4,
        'Mayo': 5, 'Junio': 6, 'Julio': 7, 'Agosto': 8,
        'Septiembre': 9, 'Octubre': 10, 'Noviembre': 11, 'Diciembre': 12
    }
    df = df.copy()
    df['Mes_num'] = df['Periodo'].map(meses)
    df['Fecha'] = pd.to_datetime(dict(year=df['Año'], month=df['Mes_num'], day=1)).dt.to_period('M')
    df.drop(columns=['Mes_num', 'Año', 'Periodo'], inplace=True)

    # Reordenar columnas para que 'Fecha' sea la primera
    cols = ['Fecha'] + [col for col in df.columns if col != 'Fecha']
    df = df[cols]

    return df

# %%
df_fecha = agregar_columna_fecha(df_procesado)

# %%
df_fecha.to_csv("construccion_inegi.csv")
